# %% [markdown]
# # 基础知识

# %% [markdown]
# $$ACC（准确率）=\frac{TP+TN}{TP+TN+FP+FN}$$
# $$P（精确率）=\frac{TP}{TP+FP}$$
# $$R（召回率）=\frac{TP}{TP+FN}$$

# %%
import sklearn as skl
skl.__version__
# Out:
# '0.19.1'

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # linear regression

# %% [markdown]
# ## 一元线性回归

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
def runplt():
    plt.figure()
    plt.title('披萨价格与直径数据',fontsize=10)
    plt.xlabel('直径（英寸）',fontsize=10)
    plt.ylabel('价格（美元）',fontsize=10)
    plt.axis([0,25,0,25])
    plt.grid(True)
    return plt

# %%
plt=runplt()
X=[[6],[8],[10],[14],[18]]
y=[[7],[9],[13],[17.5],[18]]
plt.plot(X,y,'k.')
plt.show()

# %% [markdown]
# 使用sklearn构建模型

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
model =LR()
model.fit(X,y)
print('预测一张12英寸披萨价格：$%.2f'%  model.predict([[12]])[0])
# Out:
# 预测一张12英寸披萨价格：$13.68

# %% [markdown]
# 最新版sklearn库中，predict()中值要求为2维数组。在scikit-learn里面，所有的估计器都带有fit()和predict()方法。fit()用来分析模型参数，predict()是通过fit()算出的模型参数构成的模型，对解释变量进行预测获得的值。

# %%
plt =runplt()
plt.plot(X,y,'k.')
X2= [[0], [10], [14], [25]]
model= LR()
model.fit(X,y)
y2=model.predict(X2)
plt.plot(X2,y2,'g-')
plt.show()

# %% [markdown]
# 上图为预测的线性模型：$$y=\beta X+\alpha$$

# %% [markdown]
# ## cost function 模型拟合评估

# %% [markdown]
# 下图为若干参数生成的回归直线，如何判断哪一条直线为最佳拟合？

# %%
plt = runplt()
plt.plot(X,y,'k.')
y3=[14.25,14.25,14.25,14.25]
y4=y2*0.5+5
model.fit(X[1:-1],y[1:-1])
y5=model.predict(X2)
plt.plot(X, y, 'k.')
plt.plot(X2, y2, 'g-.')
plt.plot(X2, y3, 'r-.')
plt.plot(X2, y4, 'y-.')
plt.plot(X2, y5, 'o-')
plt.show()

# %% [markdown]
# 成本函数（cost function）也叫损失函数（loss function），用来定义模型与观测值的误差。模型预
# 测的价格与训练集数据的差异称为残差（residuals）或训练误差（training errors）。后面我们会用
# 模型计算测试集，那时模型预测的价格与测试集数据的差异称为预测误差（prediction errors）或训
# 练误差（test errors）。
#
# 模型的残差是训练样本点与线性回归模型的纵向距离，如下图所示:

# %%
plt = runplt()
plt.plot(X, y, 'k.')
x2 = [[0], [10], [14], [25]]
model = LR()
model.fit(X, y)
y2 = model.predict(X2)
plt.plot(X, y, 'k.')
plt.plot(x2, y2, 'g-')

#残差预测
yr=model.predict(X)
for idx, x in enumerate(X):
    plt.plot([x, x], [y[idx], yr[idx]], 'r-')
plt.show()

# %% [markdown]
# 我们可以通过残差之和最小化实现最佳拟合，也就是说模型预测的值与训练集的数据最接近就是最佳拟合。对模型的拟合度进行评估的函数称为残差平方和（residual sum of squares）成本函数。就是让所有训练数据与模型的残差的平方之和最小化，如下所示：$$ SS_{res}=\sum_{i=1}^n(y_i-f(x_i))^2$$

# %%
print('残差平方和：%.2f'% np.mean((model.predict(X)-y)**2))
# Out:
# 残差平方和：1.75

# %% [markdown]
# 使成本函数最小化则可获得最优参数，我们先求相关系数:$$\beta=\frac{cov(x,y)}{var(x)}$$

# %% [markdown]
# 其中:$$var(x)=\frac{\sum_{i=1}^n(x_i-\bar{x})}{n-1}$$
# $$cov(x,y)=\frac{\sum_{i=1}^n(x_i-\bar{x})(y_i-\bar{y})}{n-1}$$

# %%
print(np.cov([6, 8, 10, 14, 18], [7, 9, 13, 17.5, 18])[0][1])
# Out:
# 22.650000000000002

# %%
print(np.var([6, 8, 10, 14, 18], ddof=1)) #ddof设置为1，可得样本方差无偏估计量。
# Out:
# 23.2

# %% [markdown]
# 可计算相关系数：
# $$\beta=\frac{22.65}{23.2}=0.9762$$

# %% [markdown]
# 然后根据$\alpha=\bar{y}-\beta \bar{x}$，即可得到$\alpha=12.9-0.9762\times11.2=1.9655$最终可得线性回归方程为：$$y=0.9762x+1.9655$$

# %% [markdown]
# 前面我们用学习算法对训练集进行估计，得出了模型的参数。如何评价模型在现实中的表现呢？现在让我们假设有另一组数据，作为测试集进行评估。

# %% [markdown]
# 有些度量方法可以用来评估预测效果，我们用R方（r-squared）评估匹萨价格预测的效果。R方也叫确定系数（coefficient of determination），表示模型对现实数据拟合的程度。计算R方的方法有几种。一元线性回归中R方等于皮尔逊积矩相关系数（Pearson product moment correlation coefficient或Pearson's r）的平方。

# %% [markdown]
# 首先，我们需要计算样本总体平方和，$\bar{y}$是价格$y$的均值，$y_i$是测试集的第$i$个价格样本，$n$是样本数量。$$SS_{tot}=\sum_{i=1}^n(y_i-\bar{y})^2$$
# 然后我们再计算残差平方和：$$SS_{res}=\sum_{i=1}^n(y_i-f(x_i))^2$$
# 最后根据$R$方公式：$$
# \begin{eqnarray*}
# R^2&=&1-\frac{SS_{res}}{SS_{tot}}\\&=&1-\frac{19.1982}{56.8}=0.662\end{eqnarray*}$$

# %%
# 测试集
X_test = [[8], [9], [11], [16], [12]]
y_test = [[11], [8.5], [15], [18], [11]]
model = LR()
model.fit(X, y)
model.score(X_test, y_test)
# Out:
# 0.6620052929422553

# %% [markdown]
# R方是0.6620说明测试集里面过半数的价格都可以通过模型解释。

# %% [markdown]
# ## 多元线性回归

# %% [markdown]
# R方不大说明模型预测不准确。回顾一下自己的生活经验，匹萨的价格其实还会受到其他因素的影响，此时问题无法用医院线性回归解决，此时需要更一般的模型：多元线性回归。$$y=\alpha+\beta_1x_1+\cdots+\beta_nx_n$$

# %% [markdown]
# 更新因子：直径+调料种类，矩阵第一列为1

# %%
X=[[1,6,2],[1,8,1],[1,10,0],[1,14,2],[1,18,0]]
y=[[7],[9],[13],[17.5],[18]]

# %%
from numpy.linalg import lstsq
print(lstsq(X,y)[0]) #最小二乘法计算出beta向量
# Out:
# [[1.1875    ]
#  [1.01041667]
#  [0.39583333]]
# E:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
from sklearn.linear_model import LinearRegression
X = [[6, 2], [8, 1], [10, 0], [14, 2], [18, 0]]
y = [[7], [9], [13], [17.5], [18]]

# %%
model=LinearRegression()
model.fit(X,y)
#验证集如下：
X_test = [[8, 2], [9, 0], [11, 2], [16, 2], [12, 0]]
y_test = [[11], [8.5], [15], [18], [11]]
predictions=model.predict(X_test)

# %%
for i,prediction in enumerate(predictions):
    print('Predicted: %s, Target: %s' % (prediction, y_test[i]))
# Out:
# Predicted: [10.0625], Target: [11]
# Predicted: [10.28125], Target: [8.5]
# Predicted: [13.09375], Target: [15]
# Predicted: [18.14583333], Target: [18]
# Predicted: [13.3125], Target: [11]

# %%
print('R-squared: %.2f' % model.score(X_test, y_test))
# Out:
# R-squared: 0.77

# %% [markdown]
# 可以看出增加解释变量让模型拟合效果更好了。假如解释变量和响应变量
# 的关系不是线性的呢？下面我们来研究一个特别的多元线性回归的情况，可以用来构建非线性关系模型

# %% [markdown]
# ## 多项式回归

# %% [markdown]
# 上例中，我们假设解释变量和响应变量的关系是线性的。真实情况未必如此。下面我们用多项式回归，一种特殊的多元线性回归方法，增加了指数项（ 的次数大于1）。$$y=\alpha+\beta_1x+\beta_2x^2+\cdots+\beta_nx^n$$

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
X_train = [[6], [8], [10], [14], [18]]
y_train = [[7], [9], [13], [17.5], [18]]
X_test = [[6], [8], [11], [16]]
y_test = [[8], [12], [15], [18]]

regressor = LR()
regressor.fit(X_train,y_train)
xx = np.linspace(0,26,100)
yy=regressor.predict(xx.reshape(xx.shape[0],1))
plt.plot(X_train,y_train,'k.')
plt.plot(xx, yy)
quadratic_featurizer=PolynomialFeatures(degree=2) #将数据转化为二项式
X_train_quadratic = quadratic_featurizer.fit_transform(X_train)
X_test_quadratic = quadratic_featurizer.transform(X_test)
regressor_quadratic=LR()
regressor_quadratic.fit(X_train_quadratic, y_train)
xx_quadratic = quadratic_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_quadratic.predict(xx_quadratic), 'r-')
plt.show()

# %%
print(X_train)
print(X_train_quadratic)
print(X_test)
print(X_test_quadratic)
print('一元线性回归 r-squared', regressor.score(X_test, y_test))
print('二次回归 r-squared', regressor_quadratic.score(X_test_quadratic, y_test))
# Out:
# [[6], [8], [10], [14], [18]]
# [[  1.   6.  36.]
#  [  1.   8.  64.]
#  [  1.  10. 100.]
#  [  1.  14. 196.]
#  [  1.  18. 324.]]
# [[6], [8], [11], [16]]
# [[  1.   6.  36.]
#  [  1.   8.  64.]
#  [  1.  11. 121.]
#  [  1.  16. 256.]]
# 一元线性回归 r-squared 0.809726797707665
# 二次回归 r-squared 0.8675443656345073

# %% [markdown]
# 效果如上图所示，直线为一元线性回归（R方0.81），曲线为二次回归（R方0.87），其拟合效果更佳。同样可以拟合三次回归，增加一个立方项

# %%
plt.plot(X_train, y_train, 'k.')
quadratic_featurizer = PolynomialFeatures(degree=2)
X_train_quadratic = quadratic_featurizer.fit_transform(X_train)
X_test_quadratic = quadratic_featurizer.transform(X_test)
regressor_quadratic = LR()
regressor_quadratic.fit(X_train_quadratic, y_train)
xx_quadratic = quadratic_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_quadratic.predict(xx_quadratic), 'r-')

cubic_featurizer = PolynomialFeatures(degree=3)
X_train_cubic = cubic_featurizer.fit_transform(X_train)
X_test_cubic = cubic_featurizer.transform(X_test)
regressor_cubic = LR()
regressor_cubic.fit(X_train_cubic, y_train)
xx_cubic = cubic_featurizer.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, regressor_cubic.predict(xx_cubic))
plt.show()

# %%
print(X_train_cubic)
print(X_test_cubic)
print('二次回归 r-squared', regressor_quadratic.score(X_test_quadratic, y_test))
print('三次回归 r-squared', regressor_cubic.score(X_test_cubic, y_test))
# Out:
# [[1.000e+00 6.000e+00 3.600e+01 2.160e+02]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02]
#  [1.000e+00 1.000e+01 1.000e+02 1.000e+03]
#  [1.000e+00 1.400e+01 1.960e+02 2.744e+03]
#  [1.000e+00 1.800e+01 3.240e+02 5.832e+03]]
# [[1.000e+00 6.000e+00 3.600e+01 2.160e+02]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02]
#  [1.000e+00 1.100e+01 1.210e+02 1.331e+03]
#  [1.000e+00 1.600e+01 2.560e+02 4.096e+03]]
# 二次回归 r-squared 0.8675443656345073
# 三次回归 r-squared 0.8356924156036957

# %% [markdown]
# ## 正则化

# %% [markdown]
# 正则化（Regularization）是用来防止拟合过度的一堆方法。正则化向模型中增加信息，经常是一种对抗复杂性的手段。与奥卡姆剃刀原理（Occam's razor）所说的具有最少假设的论点是最好的观点类似。正则化就是用最简单的模型解释数据。

# %% [markdown]
# scikit-learn提供了一些方法来使线性回归模型正则化。其中之一是岭回归(Ridge Regression，RR，
# 也叫Tikhonov regularization)，通过放弃最小二乘法的无偏性，以损失部分信息、降低精度为代价获
# 得回归系数更为符合实际、更可靠的回归方法。

# %% [markdown]
# $$RSS_{ridge}=\sum_{i=1}^n{(y_i-x_i^T\beta)^2} + \lambda \sum_{j=1}^p{\beta_j^2}$$

# %% [markdown]
# 岭回归增加L2范数项（相关系数向量平方和的平方根）来调整成本函数（残差平方和）。$\lambda$是调整成本函数的超参数（hyperparameter），不能自动处理，需要手动调整一种参数。 增大，
# 成本函数就变大

# %% [markdown]
# scikit-learn也提供了最小收缩和选择算子(Least absolute shrinkage and selection operator,LASSO)$$RSS_{lasso}=\sum_{i=1}^n{(y_i-x_i^T\beta)^2} + \lambda \sum_{j=1}^p{\beta_j}$$

# %% [markdown]
# 增加L1范数项（相关系数向量平方和的平方根）来调整成本函数（残差平方和）。LASSO方法会产生稀疏参数，大多数相关系数会变成0，模型只会保留一小部分特征。而岭回归还是
# 会保留大多数尽可能小的相关系数。当两个变量相关时，LASSO方法会让其中一个变量的相关系数
# 会变成0，而岭回归是将两个系数同时缩小。

# %% [markdown]
# ## 线性回归应用实例——uci winequality

# %%
df=pd.read_csv("F:\\ML\\UCI winequality\\winequality-red.csv",sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.scatter(df['alcohol'],df['quality'])
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('酒精度（Alcohol）与品质（ Quality）')
plt.show()

# %% [markdown]
# 可见酒精度与品质有较弱正相关特性，而挥发性酸度与品质呈负相关

# %%
plt.scatter(df['volatile acidity'], df['quality'])
plt.xlabel('Volatile Acidity')
plt.ylabel('Quality')
plt.title('挥发性酸度（volatile acidity）与品质（ Quality）')
plt.show()

# %%
df.corr() #关联矩阵
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# __拟合评估模型__

# %%
from sklearn.cross_validation import train_test_split as tts

# %%
X=df[list(df.columns)[:-1]]
y=df['quality']

X_train, X_test, y_train, y_test = tts(X, y)#一般25%分到test

# %%
regressor=LR()
regressor.fit(X_train,y_train)
y_predictions=regressor.predict(X_test)
print('R-squared:', regressor.score(X_test, y_test))
# Out:
# R-squared: 0.33068650281779965

# %% [markdown]
# R方表明35%的数据通过了这次测试。我们可以用交叉检验的方法来实现一个更完善的效果评估：

# %%
from sklearn.cross_validation import cross_val_score as cvs

# %%
regressor =  LR()
scores = cvs(regressor, X, y, cv=5)
print(scores.mean(), scores)
# Out:
# 0.29004162884219686 [0.13200871 0.31858135 0.34955348 0.369145   0.2809196 ]

# %% [markdown]
# 这里cross_val_score函数可以帮助我们轻松实现交叉检验功能。cv参数将数据集分成了5份。每
# 个分区都会轮流作为测试集使用。cross_val_score函数返回模拟器score方法的结果。R方结果
# 是在0.13到0.37之间，均值0.29，

# %%
plt.scatter(y_test, y_predictions)
plt.xlabel('实际品质')
plt.ylabel('预测品质')
plt.title('预测品质与实际品质')
plt.show()

# %% [markdown]
# 和假设一致，预测品质很少和实际品质完全一致。由于绝大多数训练数据都是一般品质的酒，所以这
# 个模型更适合预测一般质量的酒

# %% [markdown]
# ## 梯度下降拟合模型

# %% [markdown]
# 前面都是通过最小化成本函数来计算参数：$$\beta=(X^TX)^{-1}X^TY$$
#
# 当变量很多时，$X^TX$的计算量会非常大，也有可能有X无法求逆的情况。因此需要用到另一种参数估计方法，梯度下降法（gradient descent）。

# %% [markdown]
# 可以用梯度下降法来找出成本函数最小的模型参数值。梯度下降法会在每一步走完后，计算对应位置的导数，然后沿着梯度（变化最快的方向）相反的方向前进。总是垂直于等高线。

# %% [markdown]
# 需要注意的是，梯度下降法来找出成本函数的局部最小值。一个三维凸（convex）函数所有点构成的图行像一个碗。碗底就是唯一局部最小值。非凸函数可能有若干个局部最小值，也就是说整个图形看着像是有多个波峰和波谷。梯度下降法只能保证找到的是局部最小值，并非全局最小值。残差平方和构成的成本函数是凸函数，所以梯度下降法可以找到全局最小值。

# %% [markdown]
# 梯度下降法的一个重要超参数是步长（learning rate），用来控制蒙眼人步子的大小，就是下降幅度。如果步长足够小，那么成本函数每次迭代都会缩小，直到梯度下降法找到了最优参数为止。但是，步长缩小的过程中，计算的时间就会不断增加。如果步长太大，这个人可能会重复越过谷底，也就是梯度下降法可能在最优值附近摇摆不定。
#
#
# 如果按照每次迭代后用于更新模型参数的训练样本数量划分，有两种梯度下降法。批量梯度下降（Batch gradient descent）每次迭代都用所有训练样本。随机梯度下降（Stochastic gradientdescent，SGD）每次迭代都用一个训练样本，这个训练样本是随机选择的。当训练样本较多的时候，随机梯度下降法比批量梯度下降法更快找到最优参数。批量梯度下降法一个训练集只能产生一个结果。而SGD每次运行都会产生不同的结果。SGD也可能找不到最小值，因为升级权重的时候只用一个训练样本。它的近似值通常足够接近最小值，尤其是处理残差平方和这类凸函数的时候。

# %%
from sklearn.datasets import load_boston #使用住房数据
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler

# %%
data=load_boston()

# %%
X_train, X_test, y_train, y_test = tts(data.data, data.target)

# %%
X_scaler = StandardScaler()
y_scaler = StandardScaler()
X_train = X_scaler.fit_transform(X_train)
y_train = y_scaler.fit_transform(y_train.reshape(-1,1))
X_test = X_scaler.transform(X_test)
y_test = y_scaler.transform(y_test.reshape(-1,1)) #归一化处理

# %%
regressor = SGDRegressor(loss='squared_loss') #成本函数为残差平方函数
scores = cvs(regressor, X_train, y_train, cv=5)
print('交叉验证R方值:', scores)
print('交叉验证R方均值:', np.mean(scores))
regressor.fit(X_train, y_train)
print('测试集R方值:', regressor.score(X_test, y_test))
# Out:
# 交叉验证R方值: [0.66092547 0.76616772 0.71768784 0.63731902 0.70447769]
# 交叉验证R方均值: 0.6973155472824681
# 测试集R方值: 0.7407937209740008
# E:\Anaconda\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDRegressor'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# E:\Anaconda\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # 特征提取和处理

# %% [markdown]
# ## 分类变量特征提取

# %% [markdown]
# 分类变量通常用独热编码（One-of-K or One-Hot Encoding），通过二进制数来表示每个解释变量的特征。
#
# 例如，假设city变量有三个值：New York, San Francisco, Chapel Hill。独热编码方式就是用三位二进制数，每一位表示一个城市。

# %%
from sklearn.feature_extraction import DictVectorizer
onehot_encoder = DictVectorizer()
instances=[{'city': 'New York'},{'city': 'San Francisco'}, {'city': 'Chapel Hill'}]
print(onehot_encoder.fit_transform(instances).toarray())
# Out:
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]]

# %% [markdown]
# ## 文字特征提取

# %% [markdown]
# ## 数据标准化

# %% [markdown]
# 许多评估方法在处理标准化数据集时可以获得更好的效果。

# %%
from sklearn import preprocessing
import numpy as np
X = np.array([
[0., 0., 5., 13., 9., 1.],
[0., 0., 13., 15., 10., 15.],
[0., 3., 15., 2., 0., 11.]
])
print(preprocessing.scale(X))
# Out:
# [[ 0.         -0.70710678 -1.38873015  0.52489066  0.59299945 -1.35873244]
#  [ 0.         -0.70710678  0.46291005  0.87481777  0.81537425  1.01904933]
#  [ 0.          1.41421356  0.9258201  -1.39970842 -1.4083737   0.33968311]]
